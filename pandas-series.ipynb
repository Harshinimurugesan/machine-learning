# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.version.version
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pd.version.version
#
# AttributeError: module 'pandas' has no attribute 'version'

# %% [markdown]
# # 2.1 creating series
#
# syntax:pandas.Series(data,index=none,dtype=none)

# %%
alphabet=pd.Series([1,2,3,4],index=['a','b','c','d'])

# %%
alphabet
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# # candidate profile in series
#
# 3.1creating a candidate profile in a series

# %%
prady=pd.Series([23,9.0,'ARE',['physics','robotics','AI',]],index=['AGE','CGPA','designation','fav sub'])

# %%
prady
# Out:
# AGE                                 23
# CGPA                               9.0
# designation                        ARE
# fav sub        [physics, robotics, AI]
# dtype: object

# %% [markdown]
# # dataframe

# %%
data={'movie':['ok kanmani','jailor','mersal','ghilli'],'ratings':[10,9,8,9]}
dataframe=pd.DataFrame(data,columns=['movie','ratings'])

# %%
dataframe
# Out:
#         movie  ratings
# 0  ok kanmani       10
# 1      jailor        9
# 2      mersal        8
# 3      ghilli        9

# %% [markdown]
# # dataframe with random numbers

# %%
import numpy as np

# %%
random=pd.DataFrame(np.random.randint(0,300,size=(20,4)),columns=list('ABCD'))

# %%
random
# Out:
#       A    B    C    D
# 0    68  127   69   33
# 1    29  255  263   80
# 2    64  210  278  247
# 3    62  108  107   34
# 4    76  229   15  253
# 5    29  112  144  271
# 6   244  161  254    5
# 7    62   55   10  288
# 8   195  168  188  260
# 9   239  109  162  149
# 10   39  178   75  138
# 11   11  214   31   65
# 12  273  257  212  179
# 13  110  242  194  238
# 14   57   52  103  172
# 15  132  219   85   35
# 16  188    5   88  200
# 17  275   74  124  288
# 18  194   59  153  107
# 19  146  210  183  269

# %%
random.to_csv("C:/Users/aedpu/OneDrive/Documents/harshini/ds.csv")

# %%
data=pd.read_csv('ds.csv')
data
# Out:
#     Unnamed: 0    A    B    C    D
# 0            0   68  127   69   33
# 1            1   29  255  263   80
# 2            2   64  210  278  247
# 3            3   62  108  107   34
# 4            4   76  229   15  253
# 5            5   29  112  144  271
# 6            6  244  161  254    5
# 7            7   62   55   10  288
# 8            8  195  168  188  260
# 9            9  239  109  162  149
# 10          10   39  178   75  138
# 11          11   11  214   31   65
# 12          12  273  257  212  179
# 13          13  110  242  194  238
# 14          14   57   52  103  172
# 15          15  132  219   85   35
# 16          16  188    5   88  200
# 17          17  275   74  124  288
# 18          18  194   59  153  107
# 19          19  146  210  183  269
